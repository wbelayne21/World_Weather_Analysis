# %%
# Dependencies
import requests
from config import api_key

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Store a search term
query = "Corona Virus"
begin_date = "20200101"
end_date = "20200131"
# Search for articles published between a begin and end date
vaccine_url = f"{url}api-key={api_key}&begin_date={begin_date}&end_date={end_date}&q={query}"
vaccine_url
# or vaccine_url = url + "api-key=" + api_key + "&q=" + query + begin_date + end_date
# Build url

article = requests.get(vaccine_url).json()
article
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2021 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': 'W Sullivan article on archives of disease-causing bacteria enabling pub health specialists to predict future disease situation for a particular population',
#     'web_url': 'https://www.nytimes.com/1967/11/26/archives/science-on-the-archive-trail-of-the-causes-of-disease-virus-exposed.html',
#     'snippet': 'W Sullivan article on archives of disease-causing bacteria enabling pub health specialists to predict future disease situation for a particular population',
#     'lead_paragraph': '',
#     'print_section': 'E',
#     'print_page': '10',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Science; On the Archive Trail of the Causes of Disease Virus Exposed Specimens Collected',
#      'kicker': None,
#      'content_kicker': None,
# ...

# %%
# Retrieve articles
articles["response"]['docs'][0]["web_url"]

# %%
articles["response"]['docs'][0]["snippet"]

# %%
# BONUS: How would we get 30 results?
 for i in range(30):
        print(articles["response"]['docs'][0]["web_url"])

# HINT: Look up the page query param
